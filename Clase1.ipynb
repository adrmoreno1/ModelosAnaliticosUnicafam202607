# %% [markdown]
# <a href="https://colab.research.google.com/github/adrmoreno1/ModelosAnaliticosUnicafam202607/blob/main/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introducción a Python
# Modelos analiticos
#
# Unicafam
#
# Docente: Nicolas Mojica
#
# Estudiante: Adriana Moreno

# %% [markdown]
# ##Comentarios de codigo

# %%
#Este es un comentario de una sola linea
print('Hola mundo')
# Out:
# Hola mundo

# %%
"""Este
es un
comentario
 de varias lineas"""
# Out:
# 'Este \nes un \ncomentario\n de varias lineas'

# %% [markdown]
# ## Variables

# %%
var = "Hola mundo"
print(var)
# Out:
# Hola mundo

# %%
#Las variables deben ser el minuscula
#Las variables no pueden tener espacios
#Las variables no pueden tener caracteres especiales

# %% [markdown]
# ##Tipos de datos

# %%
#ENTEROS
entero=5
entero_explicito=int(5)

#DECIMALES
decimal=5.0
decimal_explicito=float(5.0)
type(decimal_explicito)
# Out:
# float

# %% [markdown]
# ##Operadores aritmeticos

# %%
a=5
b=3
c=a+b
print(c)
# Out:
# 8

# %%
##División entera
print(a//b)
# Out:
# 1

# %%
##Modulo
print(a%b)
# Out:
# 2

# %%
##Exponenciación
print(b**2)
# Out:
# 9

# %%
##Asignación compuesta
b+=2
print(b)
# Out:
# 5

# %% [markdown]
# ##Textos

# %%
cadena = "Python es genial"
print(cadena[5])
# Out:
# n

# %%
#Extraer la palabra python
print(cadena[0:6])
# Out:
# Python

# %%
#Extraer la palabra genial
print(cadena[10:16])
# Out:
# genial

# %%
#Concatenación de valores
palabra1 = "Hola"
palabra2 = "mundo"
print(palabra1+", "+palabra2)
# Out:
# Hola, mundo

# %%
#Cambios de formato
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
#Cambios de formato
print(cadena.lower())
# Out:
# python es genial
