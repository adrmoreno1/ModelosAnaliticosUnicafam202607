# %% [markdown]
# <a href="https://colab.research.google.com/github/adrmoreno1/ModelosAnaliticosUnicafam202607/blob/main/Taller3_listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTRODUCCION A PYTHON
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: ADRIANA MORENO
#
# Ejercicio 1: Creación y Modificación de Listas
# 1. Crea una lista llamada números que contenga los números del 1 al 5.
# 2. Añade el número 6 al final de la lista numeros.
# 3. Cambia el segundo elemento de la lista numeros a 10.
# 4. Elimina el cuarto elemento de la lista números.

# %%
##1. Crea una lista llamada números que contenga los números del 1 al 5.
numeros = [1,2,3,4,5]
print(numeros)
# Out:
# [1, 2, 3, 4, 5]

# %%
##2. Añade el número 6 al final de la lista numeros.
numeros = [1,2,3,4,5]
numeros.append(6)
print(numeros)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#3. Cambia el segundo elemento de la lista numeros a 10.
numeros[1] = 10
print(numeros)
# Out:
# [1, 10, 3, 4, 5, 6]

# %%
#4. Elimina el cuarto elemento de la lista números.
numeros.remove(4)
print(numeros)
# Out:
# [1, 10, 3, 5, 6]
